# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Aptech/Sem 6/datasets/Housing.csv")
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.shape
# Out:
# (545, 13)

# %%
cat_col = df.select_dtypes(include=['object']).columns
cat_col
# Out:
# Index(['mainroad', 'guestroom', 'basement', 'hotwaterheating',
#        'airconditioning', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
encodes = {}
for col in cat_col:
  le = LabelEncoder()
  df[col] = le.fit_transform(df[col])
  encodes[col] = dict(zip(le.classes_, le.transform(le.classes_)))

# %%
encodes
# Out:
# {'mainroad': {'no': np.int64(0), 'yes': np.int64(1)},
#  'guestroom': {'no': np.int64(0), 'yes': np.int64(1)},
#  'basement': {'no': np.int64(0), 'yes': np.int64(1)},
#  'hotwaterheating': {'no': np.int64(0), 'yes': np.int64(1)},
#  'airconditioning': {'no': np.int64(0), 'yes': np.int64(1)},
#  'prefarea': {'no': np.int64(0), 'yes': np.int64(1)},
#  'furnishingstatus': {'furnished': np.int64(0),
#   'semi-furnished': np.int64(1),
#   'unfurnished': np.int64(2)}}

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0

# %%
y = df['price']
X = df.drop('price', axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=47)

# %%
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)
model_lr.score(X_test, y_test)
# Out:
# 0.7285834750093618

# %%
model_dt = DecisionTreeRegressor()
model_dt.fit(X_train, y_train)
model_dt.score(X_test, y_test)
# Out:
# 0.1303658797567948

# %%
model_rf = RandomForestRegressor(n_estimators=300)
model_rf.fit(X_train, y_train)
model_rf.score(X_test, y_test)
# Out:
# 0.6751831599479252

# %%
from sklearn.ensemble import VotingRegressor

model_vr = VotingRegressor([('lr', LinearRegression()), ('rf', RandomForestRegressor(n_estimators=300))])
model_vr.fit(X_train, y_train)
# Out:
# VotingRegressor(estimators=[('lr', LinearRegression()),
#                             ('rf', RandomForestRegressor(n_estimators=300))])

# %%
model_vr.score(X_test, y_test)
# Out:
# 0.7221807845256761

# %%
import pickle
pickle.dump(model_lr, open('model.pkl', 'wb'))

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#          mainroad   guestroom    basement  hotwaterheating  airconditioning  \
# count  545.000000  545.000000  545.000000       545.000000       545.000000
# mean     0.858716    0.177982    0.350459         0.045872         0.315596
# std      0.348635    0.382849    0.477552         0.209399         0.465180
# ...
